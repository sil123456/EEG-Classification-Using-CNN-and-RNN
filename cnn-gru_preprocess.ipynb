# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
os.chdir("/kaggle/input/eegdata")
# Out:
# /kaggle/input/eegdata/y_test.npy
# /kaggle/input/eegdata/main.py
# /kaggle/input/eegdata/y_train_valid.npy
# /kaggle/input/eegdata/person_train_valid.npy
# /kaggle/input/eegdata/EEG_pl.py
# /kaggle/input/eegdata/X_test.npy
# /kaggle/input/eegdata/dataset.py
# /kaggle/input/eegdata/EEG_loading.ipynb
# /kaggle/input/eegdata/person_test.npy
# /kaggle/input/eegdata/X_train_valid.npy
# /kaggle/input/eegdata/classifier.py

# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,BatchNormalization,MaxPooling2D,Reshape, CuDNNGRU
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras import regularizers
from keras.callbacks import EarlyStopping

# %%
## Loading the numpy arrays corresponding to the EEG dataset

X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Printing the shapes of the numpy arrays

print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %%
## Adjusting the labels to {0,1,2,3}

# Cue onset left is 769 - 0
# Cue onset right is 770 - 1
# Cue onset foot is 771 - 2
# Cue onset tongue is 772 - 3

y_train_valid -= 769
y_test -= 769

# %%
def data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,500)
    X = X[:,:,0:500]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape)
    return total_X,total_y

X_train_valid_prep,y_train_valid_prep = data_prep(X_train_valid,y_train_valid,2,2,True)
X_test_prep,y_test_prep = data_prep(X_test,y_test,2,2,True)
# Out:
# Shape of X after trimming: (2115, 22, 500)
# Shape of X after maxpooling: (2115, 22, 250)
# Shape of X after averaging+noise and concatenating: (4230, 22, 250)
# Shape of X after subsampling and concatenating: (8460, 22, 250)
# Shape of X after trimming: (443, 22, 500)
# Shape of X after maxpooling: (443, 22, 250)
# Shape of X after averaging+noise and concatenating: (886, 22, 250)
# Shape of X after subsampling and concatenating: (1772, 22, 250)

# %%
## Creating the training and validation sets

# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(8460, 1500, replace=False)
ind_train = np.array(list(set(range(8460)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid] 
(y_train, y_valid) = y_train_valid_prep[ind_train], y_train_valid_prep[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test_prep, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of training set: (6960, 22, 250)
# Shape of validation set: (1500, 22, 250)
# Shape of training labels: (6960,)
# Shape of validation labels: (1500,)
# Shape of training labels after categorical conversion: (6960, 4)
# Shape of validation labels after categorical conversion: (1500, 4)
# Shape of test labels after categorical conversion: (1772, 4)
# Shape of training set after adding width info: (6960, 22, 250, 1)
# Shape of validation set after adding width info: (1500, 22, 250, 1)
# Shape of test set after adding width info: (1772, 22, 250, 1)
# Shape of training set after dimension reshaping: (6960, 250, 1, 22)
# Shape of validation set after dimension reshaping: (1500, 250, 1, 22)
# Shape of test set after dimension reshaping: (1772, 250, 1, 22)

# %%
# Building the CNN model using sequential class
hybrid_cnn_gru_model = Sequential()

# Conv. block 1
hybrid_cnn_gru_model.add(Conv2D(filters=16, kernel_size=(10,1), padding='same', activation='elu', input_shape=(250,1,22), kernel_regularizer=regularizers.l2(0.01)))
hybrid_cnn_gru_model.add(MaxPooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.5))

# Conv. block 2
hybrid_cnn_gru_model.add(Conv2D(filters=32, kernel_size=(10,1), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01)))
hybrid_cnn_gru_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.5))

# Conv. block 3
hybrid_cnn_gru_model.add(Conv2D(filters=64, kernel_size=(10,1), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01)))
hybrid_cnn_gru_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.5))

# Conv. block 4
hybrid_cnn_gru_model.add(Conv2D(filters=128, kernel_size=(10,1), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01)))
hybrid_cnn_gru_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.5))

# FC+GRU layers
hybrid_cnn_gru_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
hybrid_cnn_gru_model.add(Dense((100))) # FC layer with 100 units
hybrid_cnn_gru_model.add(Reshape((100,1))) # Reshape my output of FC layer so that it's compatible
hybrid_cnn_gru_model.add(CuDNNGRU(10, input_shape=(100,1), return_sequences=False))


# Output layer with Softmax activation 
hybrid_cnn_gru_model.add(Dense(4, activation='softmax', kernel_regularizer=regularizers.l2(0.01))) # Output FC layer with softmax activation


# Printing the model summary
hybrid_cnn_gru_model.summary()
# Out:
# 2022-03-12 23:27:41.285686: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 23:27:41.377065: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 23:27:41.377815: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 23:27:41.378928: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-12 23:27:41.379930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 23:27:41.380589: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 23:27:41.381169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 23:27:43.191814: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 23:27:43.192602: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 23:27:43.193239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 23:27:43.193817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 250, 1, 16)        3536
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 84, 1, 16)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 84, 1, 16)         64
# _________________________________________________________________
# dropout (Dropout)            (None, 84, 1, 16)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 84, 1, 32)         5152
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 1, 32)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 1, 32)         128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 1, 32)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 1, 64)         20544
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 1, 64)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 10, 1, 64)         256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 1, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 1, 128)        82048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 1, 128)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 1, 128)         512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               51300
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 1)            0
# _________________________________________________________________
# cu_dnngru (CuDNNGRU)         (None, 10)                390
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 44
# =================================================================
# Total params: 163,974
# Trainable params: 163,494
# Non-trainable params: 480
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

learning_rate = 1e-4
epochs = 200
hybrid_cnn_gru_optimizer = Adam(learning_rate=learning_rate)

# %%
# Compiling the model
hybrid_cnn_gru_model.compile(loss='categorical_crossentropy',
                 optimizer=hybrid_cnn_gru_optimizer,
                 metrics=['accuracy'])

# won't stop here
callbacks = [EarlyStopping(monitor='val_accuracy', patience=25)]

# Training and validating the model
hybrid_cnn_gru_model_results = hybrid_cnn_gru_model.fit(x_train,
             y_train,
             batch_size=32,
             epochs=epochs,
             validation_data=(x_valid, y_valid), 
             callbacks=callbacks,                                             
             verbose=True)
# Out:
# 2022-03-12 23:27:44.179513: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-03-12 23:27:46.442613: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 218/218 [==============================] - 11s 13ms/step - loss: 3.0704 - accuracy: 0.2776 - val_loss: 2.9522 - val_accuracy: 0.3147
# Epoch 2/200
# 218/218 [==============================] - 2s 10ms/step - loss: 2.9019 - accuracy: 0.3056 - val_loss: 2.7979 - val_accuracy: 0.3447
# Epoch 3/200
# 218/218 [==============================] - 2s 10ms/step - loss: 2.7520 - accuracy: 0.3207 - val_loss: 2.6564 - val_accuracy: 0.3480
# Epoch 4/200
# 218/218 [==============================] - 2s 11ms/step - loss: 2.6169 - accuracy: 0.3329 - val_loss: 2.5301 - val_accuracy: 0.3393
# Epoch 5/200
# 218/218 [==============================] - 2s 10ms/step - loss: 2.4956 - accuracy: 0.3395 - val_loss: 2.4046 - val_accuracy: 0.3367
# Epoch 6/200
# 218/218 [==============================] - 2s 10ms/step - loss: 2.3741 - accuracy: 0.3539 - val_loss: 2.2914 - val_accuracy: 0.3647
# Epoch 7/200
# 218/218 [==============================] - 2s 10ms/step - loss: 2.2706 - accuracy: 0.3598 - val_loss: 2.1844 - val_accuracy: 0.3807
# Epoch 8/200
# 218/218 [==============================] - 2s 10ms/step - loss: 2.1676 - accuracy: 0.3751 - val_loss: 2.0896 - val_accuracy: 0.4100
# Epoch 9/200
# 218/218 [==============================] - 2s 11ms/step - loss: 2.0800 - accuracy: 0.3912 - val_loss: 2.0006 - val_accuracy: 0.4273
# Epoch 10/200
# 218/218 [==============================] - 2s 10ms/step - loss: 2.0007 - accuracy: 0.4003 - val_loss: 1.9296 - val_accuracy: 0.4533
# Epoch 11/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.9287 - accuracy: 0.4141 - val_loss: 1.8562 - val_accuracy: 0.4700
# Epoch 12/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.8678 - accuracy: 0.4155 - val_loss: 1.7996 - val_accuracy: 0.4880
# Epoch 13/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.7984 - accuracy: 0.4302 - val_loss: 1.7432 - val_accuracy: 0.5027
# Epoch 14/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.7432 - accuracy: 0.4527 - val_loss: 1.6845 - val_accuracy: 0.5060
# Epoch 15/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.6891 - accuracy: 0.4603 - val_loss: 1.6378 - val_accuracy: 0.4853
# Epoch 16/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.6432 - accuracy: 0.4747 - val_loss: 1.5996 - val_accuracy: 0.4980
# Epoch 17/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.6041 - accuracy: 0.4823 - val_loss: 1.5627 - val_accuracy: 0.4980
# Epoch 18/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.5568 - accuracy: 0.5020 - val_loss: 1.5092 - val_accuracy: 0.5133
# Epoch 19/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.5294 - accuracy: 0.4941 - val_loss: 1.4905 - val_accuracy: 0.5253
# Epoch 20/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.4971 - accuracy: 0.5039 - val_loss: 1.4568 - val_accuracy: 0.5300
# Epoch 21/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.4662 - accuracy: 0.5211 - val_loss: 1.4254 - val_accuracy: 0.5420
# Epoch 22/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.4418 - accuracy: 0.5184 - val_loss: 1.3928 - val_accuracy: 0.5587
# Epoch 23/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.4156 - accuracy: 0.5273 - val_loss: 1.3634 - val_accuracy: 0.5500
# Epoch 24/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.3832 - accuracy: 0.5493 - val_loss: 1.3462 - val_accuracy: 0.5647
# Epoch 25/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.3725 - accuracy: 0.5427 - val_loss: 1.3078 - val_accuracy: 0.5880
# Epoch 26/200
# 218/218 [==============================] - 3s 12ms/step - loss: 1.3540 - accuracy: 0.5499 - val_loss: 1.2831 - val_accuracy: 0.5913
# Epoch 27/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.3315 - accuracy: 0.5570 - val_loss: 1.2577 - val_accuracy: 0.6053
# Epoch 28/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.3148 - accuracy: 0.5651 - val_loss: 1.2407 - val_accuracy: 0.6120
# Epoch 29/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.2974 - accuracy: 0.5685 - val_loss: 1.2176 - val_accuracy: 0.6307
# Epoch 30/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.2893 - accuracy: 0.5746 - val_loss: 1.2084 - val_accuracy: 0.6153
# Epoch 31/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.2668 - accuracy: 0.5823 - val_loss: 1.1770 - val_accuracy: 0.6380
# Epoch 32/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.2518 - accuracy: 0.5845 - val_loss: 1.1633 - val_accuracy: 0.6507
# Epoch 33/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.2485 - accuracy: 0.5904 - val_loss: 1.1414 - val_accuracy: 0.6640
# Epoch 34/200
# 218/218 [==============================] - 3s 12ms/step - loss: 1.2173 - accuracy: 0.6034 - val_loss: 1.1234 - val_accuracy: 0.6720
# Epoch 35/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.2097 - accuracy: 0.6118 - val_loss: 1.1095 - val_accuracy: 0.6747
# Epoch 36/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.1959 - accuracy: 0.6141 - val_loss: 1.0957 - val_accuracy: 0.6847
# Epoch 37/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.1909 - accuracy: 0.6157 - val_loss: 1.1025 - val_accuracy: 0.6747
# Epoch 38/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.1776 - accuracy: 0.6253 - val_loss: 1.0737 - val_accuracy: 0.6947
# Epoch 39/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.1737 - accuracy: 0.6264 - val_loss: 1.0635 - val_accuracy: 0.6980
# Epoch 40/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.1622 - accuracy: 0.6292 - val_loss: 1.0451 - val_accuracy: 0.7100
# Epoch 41/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.1508 - accuracy: 0.6297 - val_loss: 1.0453 - val_accuracy: 0.7093
# Epoch 42/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.1397 - accuracy: 0.6371 - val_loss: 1.0166 - val_accuracy: 0.7240
# Epoch 43/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.1304 - accuracy: 0.6425 - val_loss: 0.9991 - val_accuracy: 0.7347
# Epoch 44/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.1190 - accuracy: 0.6519 - val_loss: 1.0035 - val_accuracy: 0.7173
# Epoch 45/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.1068 - accuracy: 0.6605 - val_loss: 0.9793 - val_accuracy: 0.7513
# Epoch 46/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.1006 - accuracy: 0.6606 - val_loss: 0.9652 - val_accuracy: 0.7533
# Epoch 47/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.0963 - accuracy: 0.6678 - val_loss: 0.9525 - val_accuracy: 0.7513
# Epoch 48/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.0756 - accuracy: 0.6726 - val_loss: 0.9438 - val_accuracy: 0.7673
# Epoch 49/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.0723 - accuracy: 0.6723 - val_loss: 0.9256 - val_accuracy: 0.7733
# Epoch 50/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.0733 - accuracy: 0.6730 - val_loss: 0.9134 - val_accuracy: 0.7713
# Epoch 51/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.0484 - accuracy: 0.6842 - val_loss: 0.9097 - val_accuracy: 0.7740
# Epoch 52/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.0564 - accuracy: 0.6819 - val_loss: 0.8904 - val_accuracy: 0.7833
# Epoch 53/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.0438 - accuracy: 0.6905 - val_loss: 0.8771 - val_accuracy: 0.7933
# Epoch 54/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.0216 - accuracy: 0.6955 - val_loss: 0.8685 - val_accuracy: 0.7947
# Epoch 55/200
# 218/218 [==============================] - 2s 11ms/step - loss: 1.0269 - accuracy: 0.6922 - val_loss: 0.8637 - val_accuracy: 0.7947
# Epoch 56/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.0162 - accuracy: 0.7026 - val_loss: 0.8498 - val_accuracy: 0.8027
# Epoch 57/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.0084 - accuracy: 0.6964 - val_loss: 0.8636 - val_accuracy: 0.7900
# Epoch 58/200
# 218/218 [==============================] - 2s 10ms/step - loss: 1.0067 - accuracy: 0.7046 - val_loss: 0.8299 - val_accuracy: 0.8227
# Epoch 59/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.9823 - accuracy: 0.7138 - val_loss: 0.8124 - val_accuracy: 0.8173
# Epoch 60/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9823 - accuracy: 0.7152 - val_loss: 0.8103 - val_accuracy: 0.8160
# Epoch 61/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9737 - accuracy: 0.7164 - val_loss: 0.8068 - val_accuracy: 0.8240
# Epoch 62/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9722 - accuracy: 0.7172 - val_loss: 0.8102 - val_accuracy: 0.8120
# Epoch 63/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9647 - accuracy: 0.7216 - val_loss: 0.7870 - val_accuracy: 0.8293
# Epoch 64/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.9496 - accuracy: 0.7307 - val_loss: 0.7713 - val_accuracy: 0.8347
# Epoch 65/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9544 - accuracy: 0.7227 - val_loss: 0.7732 - val_accuracy: 0.8287
# Epoch 66/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9661 - accuracy: 0.7211 - val_loss: 0.7543 - val_accuracy: 0.8333
# Epoch 67/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9487 - accuracy: 0.7233 - val_loss: 0.7506 - val_accuracy: 0.8433
# Epoch 68/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9387 - accuracy: 0.7332 - val_loss: 0.7325 - val_accuracy: 0.8453
# Epoch 69/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.9391 - accuracy: 0.7355 - val_loss: 0.7275 - val_accuracy: 0.8547
# Epoch 70/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.9222 - accuracy: 0.7407 - val_loss: 0.7260 - val_accuracy: 0.8593
# Epoch 71/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9330 - accuracy: 0.7343 - val_loss: 0.7231 - val_accuracy: 0.8567
# Epoch 72/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9227 - accuracy: 0.7420 - val_loss: 0.7112 - val_accuracy: 0.8527
# Epoch 73/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.9182 - accuracy: 0.7398 - val_loss: 0.7240 - val_accuracy: 0.8533
# Epoch 74/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.9023 - accuracy: 0.7476 - val_loss: 0.6977 - val_accuracy: 0.8647
# Epoch 75/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8977 - accuracy: 0.7513 - val_loss: 0.7009 - val_accuracy: 0.8613
# Epoch 76/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8983 - accuracy: 0.7457 - val_loss: 0.6925 - val_accuracy: 0.8653
# Epoch 77/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8862 - accuracy: 0.7549 - val_loss: 0.6887 - val_accuracy: 0.8687
# Epoch 78/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8896 - accuracy: 0.7527 - val_loss: 0.6701 - val_accuracy: 0.8707
# Epoch 79/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.8855 - accuracy: 0.7537 - val_loss: 0.6750 - val_accuracy: 0.8673
# Epoch 80/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8873 - accuracy: 0.7506 - val_loss: 0.6676 - val_accuracy: 0.8727
# Epoch 81/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8672 - accuracy: 0.7629 - val_loss: 0.6648 - val_accuracy: 0.8747
# Epoch 82/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8762 - accuracy: 0.7542 - val_loss: 0.6545 - val_accuracy: 0.8720
# Epoch 83/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8630 - accuracy: 0.7626 - val_loss: 0.6514 - val_accuracy: 0.8733
# Epoch 84/200
# 218/218 [==============================] - 3s 13ms/step - loss: 0.8567 - accuracy: 0.7700 - val_loss: 0.6342 - val_accuracy: 0.8780
# Epoch 85/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8532 - accuracy: 0.7691 - val_loss: 0.6320 - val_accuracy: 0.8860
# Epoch 86/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8529 - accuracy: 0.7629 - val_loss: 0.6343 - val_accuracy: 0.8807
# Epoch 87/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8548 - accuracy: 0.7647 - val_loss: 0.6302 - val_accuracy: 0.8867
# Epoch 88/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8608 - accuracy: 0.7644 - val_loss: 0.6235 - val_accuracy: 0.8933
# Epoch 89/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8481 - accuracy: 0.7668 - val_loss: 0.6178 - val_accuracy: 0.8913
# Epoch 90/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8416 - accuracy: 0.7756 - val_loss: 0.6300 - val_accuracy: 0.8853
# Epoch 91/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8460 - accuracy: 0.7688 - val_loss: 0.6043 - val_accuracy: 0.8993
# Epoch 92/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8435 - accuracy: 0.7718 - val_loss: 0.6052 - val_accuracy: 0.9013
# Epoch 93/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8346 - accuracy: 0.7754 - val_loss: 0.6053 - val_accuracy: 0.8973
# Epoch 94/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8317 - accuracy: 0.7761 - val_loss: 0.6029 - val_accuracy: 0.9047
# Epoch 95/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8272 - accuracy: 0.7772 - val_loss: 0.6089 - val_accuracy: 0.9027
# Epoch 96/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8308 - accuracy: 0.7776 - val_loss: 0.5967 - val_accuracy: 0.9060
# Epoch 97/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8211 - accuracy: 0.7774 - val_loss: 0.5908 - val_accuracy: 0.9060
# Epoch 98/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8317 - accuracy: 0.7751 - val_loss: 0.5941 - val_accuracy: 0.8967
# Epoch 99/200
# 218/218 [==============================] - 3s 13ms/step - loss: 0.8177 - accuracy: 0.7839 - val_loss: 0.5907 - val_accuracy: 0.9007
# Epoch 100/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8190 - accuracy: 0.7772 - val_loss: 0.5997 - val_accuracy: 0.9007
# Epoch 101/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8051 - accuracy: 0.7846 - val_loss: 0.5789 - val_accuracy: 0.9080
# Epoch 102/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8240 - accuracy: 0.7739 - val_loss: 0.6101 - val_accuracy: 0.8787
# Epoch 103/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.8013 - accuracy: 0.7881 - val_loss: 0.5619 - val_accuracy: 0.9167
# Epoch 104/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8080 - accuracy: 0.7789 - val_loss: 0.5650 - val_accuracy: 0.9167
# Epoch 105/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7914 - accuracy: 0.7954 - val_loss: 0.5780 - val_accuracy: 0.9027
# Epoch 106/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8001 - accuracy: 0.7862 - val_loss: 0.5652 - val_accuracy: 0.9120
# Epoch 107/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7933 - accuracy: 0.7901 - val_loss: 0.5607 - val_accuracy: 0.9147
# Epoch 108/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.8065 - accuracy: 0.7838 - val_loss: 0.5535 - val_accuracy: 0.9160
# Epoch 109/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.8006 - accuracy: 0.7841 - val_loss: 0.5638 - val_accuracy: 0.9060
# Epoch 110/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7956 - accuracy: 0.7855 - val_loss: 0.5496 - val_accuracy: 0.9120
# Epoch 111/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7861 - accuracy: 0.7977 - val_loss: 0.5552 - val_accuracy: 0.9080
# Epoch 112/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7866 - accuracy: 0.7917 - val_loss: 0.5505 - val_accuracy: 0.9180
# Epoch 113/200
# 218/218 [==============================] - 3s 12ms/step - loss: 0.7946 - accuracy: 0.7907 - val_loss: 0.5425 - val_accuracy: 0.9267
# Epoch 114/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7747 - accuracy: 0.7967 - val_loss: 0.5411 - val_accuracy: 0.9227
# Epoch 115/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7837 - accuracy: 0.7953 - val_loss: 0.5449 - val_accuracy: 0.9200
# Epoch 116/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7824 - accuracy: 0.7899 - val_loss: 0.5355 - val_accuracy: 0.9247
# Epoch 117/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7796 - accuracy: 0.7978 - val_loss: 0.5382 - val_accuracy: 0.9240
# Epoch 118/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7846 - accuracy: 0.7938 - val_loss: 0.5300 - val_accuracy: 0.9240
# Epoch 119/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7749 - accuracy: 0.7974 - val_loss: 0.5318 - val_accuracy: 0.9167
# Epoch 120/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7698 - accuracy: 0.7957 - val_loss: 0.5405 - val_accuracy: 0.9180
# Epoch 121/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7834 - accuracy: 0.7864 - val_loss: 0.5229 - val_accuracy: 0.9320
# Epoch 122/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7603 - accuracy: 0.8030 - val_loss: 0.5240 - val_accuracy: 0.9233
# Epoch 123/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7622 - accuracy: 0.8014 - val_loss: 0.5204 - val_accuracy: 0.9347
# Epoch 124/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7853 - accuracy: 0.7899 - val_loss: 0.5226 - val_accuracy: 0.9267
# Epoch 125/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7625 - accuracy: 0.8029 - val_loss: 0.5129 - val_accuracy: 0.9313
# Epoch 126/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7721 - accuracy: 0.7927 - val_loss: 0.5271 - val_accuracy: 0.9273
# Epoch 127/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7625 - accuracy: 0.8020 - val_loss: 0.5271 - val_accuracy: 0.9200
# Epoch 128/200
# 218/218 [==============================] - 3s 12ms/step - loss: 0.7512 - accuracy: 0.8040 - val_loss: 0.5120 - val_accuracy: 0.9300
# Epoch 129/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7571 - accuracy: 0.8063 - val_loss: 0.5239 - val_accuracy: 0.9240
# Epoch 130/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7600 - accuracy: 0.8042 - val_loss: 0.5265 - val_accuracy: 0.9233
# Epoch 131/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7689 - accuracy: 0.7940 - val_loss: 0.5084 - val_accuracy: 0.9333
# Epoch 132/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7638 - accuracy: 0.7960 - val_loss: 0.5072 - val_accuracy: 0.9300
# Epoch 133/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7629 - accuracy: 0.7947 - val_loss: 0.5121 - val_accuracy: 0.9320
# Epoch 134/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7521 - accuracy: 0.8046 - val_loss: 0.5072 - val_accuracy: 0.9340
# Epoch 135/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7428 - accuracy: 0.8102 - val_loss: 0.5015 - val_accuracy: 0.9360
# Epoch 136/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7417 - accuracy: 0.8095 - val_loss: 0.4929 - val_accuracy: 0.9413
# Epoch 137/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7526 - accuracy: 0.8055 - val_loss: 0.4952 - val_accuracy: 0.9447
# Epoch 138/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7415 - accuracy: 0.8080 - val_loss: 0.4946 - val_accuracy: 0.9373
# Epoch 139/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7451 - accuracy: 0.8014 - val_loss: 0.4875 - val_accuracy: 0.9420
# Epoch 140/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7463 - accuracy: 0.8075 - val_loss: 0.4972 - val_accuracy: 0.9367
# Epoch 141/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7392 - accuracy: 0.8053 - val_loss: 0.5005 - val_accuracy: 0.9333
# Epoch 142/200
# 218/218 [==============================] - 3s 12ms/step - loss: 0.7516 - accuracy: 0.8011 - val_loss: 0.4903 - val_accuracy: 0.9387
# Epoch 143/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7425 - accuracy: 0.8075 - val_loss: 0.4960 - val_accuracy: 0.9367
# Epoch 144/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7517 - accuracy: 0.8039 - val_loss: 0.4831 - val_accuracy: 0.9447
# Epoch 145/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7481 - accuracy: 0.8096 - val_loss: 0.4803 - val_accuracy: 0.9353
# Epoch 146/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7401 - accuracy: 0.8128 - val_loss: 0.4780 - val_accuracy: 0.9453
# Epoch 147/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7399 - accuracy: 0.8124 - val_loss: 0.4850 - val_accuracy: 0.9327
# Epoch 148/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7318 - accuracy: 0.8101 - val_loss: 0.5054 - val_accuracy: 0.9347
# Epoch 149/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7345 - accuracy: 0.8083 - val_loss: 0.4782 - val_accuracy: 0.9413
# Epoch 150/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7317 - accuracy: 0.8151 - val_loss: 0.4936 - val_accuracy: 0.9367
# Epoch 151/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7296 - accuracy: 0.8088 - val_loss: 0.4717 - val_accuracy: 0.9487
# Epoch 152/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7280 - accuracy: 0.8147 - val_loss: 0.4694 - val_accuracy: 0.9473
# Epoch 153/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7269 - accuracy: 0.8128 - val_loss: 0.4745 - val_accuracy: 0.9400
# Epoch 154/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7359 - accuracy: 0.8125 - val_loss: 0.4803 - val_accuracy: 0.9453
# Epoch 155/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7303 - accuracy: 0.8145 - val_loss: 0.4809 - val_accuracy: 0.9393
# Epoch 156/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7215 - accuracy: 0.8170 - val_loss: 0.4648 - val_accuracy: 0.9513
# Epoch 157/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7175 - accuracy: 0.8201 - val_loss: 0.4691 - val_accuracy: 0.9460
# Epoch 158/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7243 - accuracy: 0.8136 - val_loss: 0.4794 - val_accuracy: 0.9433
# Epoch 159/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7199 - accuracy: 0.8145 - val_loss: 0.4715 - val_accuracy: 0.9413
# Epoch 160/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7239 - accuracy: 0.8165 - val_loss: 0.4723 - val_accuracy: 0.9480
# Epoch 161/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7297 - accuracy: 0.8105 - val_loss: 0.4708 - val_accuracy: 0.9473
# Epoch 162/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7172 - accuracy: 0.8174 - val_loss: 0.4740 - val_accuracy: 0.9467
# Epoch 163/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7168 - accuracy: 0.8159 - val_loss: 0.4732 - val_accuracy: 0.9380
# Epoch 164/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7209 - accuracy: 0.8164 - val_loss: 0.4733 - val_accuracy: 0.9480
# Epoch 165/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7279 - accuracy: 0.8119 - val_loss: 0.4615 - val_accuracy: 0.9513
# Epoch 166/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7167 - accuracy: 0.8134 - val_loss: 0.4690 - val_accuracy: 0.9440
# Epoch 167/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7147 - accuracy: 0.8217 - val_loss: 0.4833 - val_accuracy: 0.9433
# Epoch 168/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7139 - accuracy: 0.8174 - val_loss: 0.4708 - val_accuracy: 0.9453
# Epoch 169/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7114 - accuracy: 0.8181 - val_loss: 0.4592 - val_accuracy: 0.9533
# Epoch 170/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7107 - accuracy: 0.8180 - val_loss: 0.4532 - val_accuracy: 0.9553
# Epoch 171/200
# 218/218 [==============================] - 3s 12ms/step - loss: 0.7176 - accuracy: 0.8193 - val_loss: 0.4520 - val_accuracy: 0.9580
# Epoch 172/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7148 - accuracy: 0.8187 - val_loss: 0.4635 - val_accuracy: 0.9493
# Epoch 173/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7017 - accuracy: 0.8244 - val_loss: 0.4540 - val_accuracy: 0.9520
# Epoch 174/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7167 - accuracy: 0.8149 - val_loss: 0.4574 - val_accuracy: 0.9500
# Epoch 175/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7073 - accuracy: 0.8188 - val_loss: 0.4568 - val_accuracy: 0.9513
# Epoch 176/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7032 - accuracy: 0.8241 - val_loss: 0.4514 - val_accuracy: 0.9587
# Epoch 177/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6924 - accuracy: 0.8287 - val_loss: 0.4508 - val_accuracy: 0.9560
# Epoch 178/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.7002 - accuracy: 0.8228 - val_loss: 0.4421 - val_accuracy: 0.9547
# Epoch 179/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7114 - accuracy: 0.8170 - val_loss: 0.4421 - val_accuracy: 0.9567
# Epoch 180/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6980 - accuracy: 0.8259 - val_loss: 0.4502 - val_accuracy: 0.9547
# Epoch 181/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6967 - accuracy: 0.8292 - val_loss: 0.4402 - val_accuracy: 0.9580
# Epoch 182/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6963 - accuracy: 0.8270 - val_loss: 0.4553 - val_accuracy: 0.9433
# Epoch 183/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.6953 - accuracy: 0.8257 - val_loss: 0.4553 - val_accuracy: 0.9473
# Epoch 184/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7038 - accuracy: 0.8226 - val_loss: 0.4460 - val_accuracy: 0.9467
# Epoch 185/200
# 218/218 [==============================] - 3s 11ms/step - loss: 0.6936 - accuracy: 0.8289 - val_loss: 0.4556 - val_accuracy: 0.9467
# Epoch 186/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7064 - accuracy: 0.8224 - val_loss: 0.4406 - val_accuracy: 0.9553
# Epoch 187/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6874 - accuracy: 0.8299 - val_loss: 0.4431 - val_accuracy: 0.9547
# Epoch 188/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.6978 - accuracy: 0.8257 - val_loss: 0.4381 - val_accuracy: 0.9587
# Epoch 189/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6929 - accuracy: 0.8280 - val_loss: 0.4302 - val_accuracy: 0.9547
# Epoch 190/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6929 - accuracy: 0.8241 - val_loss: 0.4380 - val_accuracy: 0.9553
# Epoch 191/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7003 - accuracy: 0.8240 - val_loss: 0.4369 - val_accuracy: 0.9560
# Epoch 192/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6960 - accuracy: 0.8253 - val_loss: 0.4427 - val_accuracy: 0.9533
# Epoch 193/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.6987 - accuracy: 0.8213 - val_loss: 0.4438 - val_accuracy: 0.9540
# Epoch 194/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6951 - accuracy: 0.8253 - val_loss: 0.4445 - val_accuracy: 0.9527
# Epoch 195/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6771 - accuracy: 0.8338 - val_loss: 0.4349 - val_accuracy: 0.9560
# Epoch 196/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.7009 - accuracy: 0.8228 - val_loss: 0.4478 - val_accuracy: 0.9500
# Epoch 197/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6975 - accuracy: 0.8244 - val_loss: 0.4368 - val_accuracy: 0.9540
# Epoch 198/200
# 218/218 [==============================] - 2s 11ms/step - loss: 0.6848 - accuracy: 0.8251 - val_loss: 0.4258 - val_accuracy: 0.9607
# Epoch 199/200
# 218/218 [==============================] - 2s 10ms/step - loss: 0.6777 - accuracy: 0.8322 - val_loss: 0.4251 - val_accuracy: 0.9633
# Epoch 200/200
# 218/218 [==============================] - 3s 12ms/step - loss: 0.6902 - accuracy: 0.8266 - val_loss: 0.4301 - val_accuracy: 0.9613

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_gru_model_results.history['accuracy'])
plt.plot(hybrid_cnn_gru_model_results.history['val_accuracy'])
plt.title('Hybrid CNN-GRU model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_gru_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_gru_model_results.history['val_loss'],'o')
plt.title('Hybrid CNN-GRU model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the hybrid CNN-GRU model

hybrid_cnn_gru_score = hybrid_cnn_gru_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hybrid CNN-GRU model:',hybrid_cnn_gru_score[1])
# Out:
# Test accuracy of the hybrid CNN-GRU model: 0.705981969833374

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

y_pred_test = hybrid_cnn_gru_model.predict(x_test)


# classification_report
for i,x in enumerate(['left','right','foot','tongue']):
    print(x)
    y_pred = np.where(y_pred_test[:,i]>0.5,1,0)
    
    print(classification_report(y_test[:,i], y_pred))
# Out:
# left
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.94      0.91      1328
#          1.0       0.78      0.66      0.72       444
#
#     accuracy                           0.87      1772
#    macro avg       0.84      0.80      0.82      1772
# weighted avg       0.86      0.87      0.86      1772
#
# right
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.88      0.88      1264
#          1.0       0.71      0.70      0.70       508
#
#     accuracy                           0.83      1772
#    macro avg       0.79      0.79      0.79      1772
# weighted avg       0.83      0.83      0.83      1772
#
# foot
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.92      0.91      1388
#          1.0       0.69      0.62      0.66       384
#
#     accuracy                           0.86      1772
#    macro avg       0.80      0.77      0.78      1772
# weighted avg       0.85      0.86      0.86      1772
#
# tongue
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.93      0.92      1336
#          1.0       0.78      0.73      0.75       436
#
#     accuracy                           0.88      1772
#    macro avg       0.85      0.83      0.84      1772
# weighted avg       0.88      0.88      0.88      1772
