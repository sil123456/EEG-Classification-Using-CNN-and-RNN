# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
os.chdir("/kaggle/input/eegdata")
# Out:
# /kaggle/input/eegdata/y_test.npy
# /kaggle/input/eegdata/main.py
# /kaggle/input/eegdata/y_train_valid.npy
# /kaggle/input/eegdata/person_train_valid.npy
# /kaggle/input/eegdata/EEG_pl.py
# /kaggle/input/eegdata/X_test.npy
# /kaggle/input/eegdata/dataset.py
# /kaggle/input/eegdata/EEG_loading.ipynb
# /kaggle/input/eegdata/person_test.npy
# /kaggle/input/eegdata/X_train_valid.npy
# /kaggle/input/eegdata/classifier.py

# %% [markdown]
# ### Shape of data

# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,BatchNormalization,MaxPooling2D,Reshape
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras import regularizers

# %%
## Loading the numpy arrays corresponding to the EEG dataset



X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Printing the shapes of the numpy arrays

print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %%
## Adjusting the labels to {0,1,2,3}

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

# %%
## Creating the training and validation sets

# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(2115, 500, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(x_train, x_valid) = X_train_valid[ind_train], X_train_valid[ind_valid] 
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of training set: (1615, 22, 1000)
# Shape of validation set: (500, 22, 1000)
# Shape of training labels: (1615,)
# Shape of validation labels: (500,)
# Shape of training labels after categorical conversion: (1615, 4)
# Shape of validation labels after categorical conversion: (500, 4)
# Shape of test labels after categorical conversion: (443, 4)
# Shape of training set after adding width info: (1615, 22, 1000, 1)
# Shape of validation set after adding width info: (500, 22, 1000, 1)
# Shape of test set after adding width info: (443, 22, 1000, 1)
# Shape of training set after dimension reshaping: (1615, 1000, 1, 22)
# Shape of validation set after dimension reshaping: (500, 1000, 1, 22)
# Shape of test set after dimension reshaping: (443, 1000, 1, 22)

# %%
# Building the CNN model using sequential class
basic_cnn_model = Sequential()

# Conv. block 1
basic_cnn_model.add(Conv2D(filters=16, kernel_size=(10,1), padding='same', activation='elu', input_shape=(1000,1,22),kernel_regularizer=regularizers.l2(0.01)))
basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.5))

# Conv. block 2
basic_cnn_model.add(Conv2D(filters=32, kernel_size=(10,1), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01)))
basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.5))

# Conv. block 3
basic_cnn_model.add(Conv2D(filters=64, kernel_size=(10,1), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01)))
basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.5))

# Conv. block 4
basic_cnn_model.add(Conv2D(filters=128, kernel_size=(10,1), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01)))
basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.5))

# Output layer with Softmax activation
basic_cnn_model.add(Flatten()) # Flattens the input
basic_cnn_model.add(Dense(4, activation='softmax', kernel_regularizer=regularizers.l2(0.01))) # Output FC layer with softmax activation

# Printing the model summary
basic_cnn_model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_49 (Conv2D)           (None, 1000, 1, 16)       3536
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 334, 1, 16)        0
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 334, 1, 16)        64
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 334, 1, 16)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 334, 1, 32)        5152
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 112, 1, 32)        0
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 112, 1, 32)        128
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 112, 1, 32)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 112, 1, 64)        20544
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 38, 1, 64)         0
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 38, 1, 64)         256
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 38, 1, 64)         0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 38, 1, 128)        82048
# _________________________________________________________________
# max_pooling2d_52 (MaxPooling (None, 13, 1, 128)        0
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 13, 1, 128)        512
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 13, 1, 128)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1664)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 4)                 6660
# =================================================================
# Total params: 118,900
# Trainable params: 118,420
# Non-trainable params: 480
# _________________________________________________________________

# %%
# Model parameters
from tensorflow.keras.optimizers import Adam
learning_rate = 1e-3
epochs = 200
cnn_optimizer = Adam(lr=learning_rate)

# %%
# Compiling the model
from keras.callbacks import EarlyStopping

basic_cnn_model.compile(loss='categorical_crossentropy',
                 optimizer=cnn_optimizer,
                 metrics=['accuracy'])

callbacks = [EarlyStopping(monitor='val_accuracy', patience=25)]

# Training and validating the model
basic_cnn_model_results = basic_cnn_model.fit(x_train,
             y_train,
             batch_size=32,
             epochs=epochs,
             validation_data=(x_valid, y_valid),
             #callbacks=callbacks,
             verbose=True)
# Out:
# Epoch 1/200
# 51/51 [==============================] - 2s 13ms/step - loss: 3.9823 - accuracy: 0.2848 - val_loss: 3.3361 - val_accuracy: 0.3480
# Epoch 2/200
# 51/51 [==============================] - 0s 7ms/step - loss: 3.7271 - accuracy: 0.3294 - val_loss: 3.2523 - val_accuracy: 0.3460
# Epoch 3/200
# 51/51 [==============================] - 0s 7ms/step - loss: 3.5769 - accuracy: 0.3344 - val_loss: 3.2998 - val_accuracy: 0.3200
# Epoch 4/200
# 51/51 [==============================] - 0s 7ms/step - loss: 3.3640 - accuracy: 0.3628 - val_loss: 3.1537 - val_accuracy: 0.3340
# Epoch 5/200
# 51/51 [==============================] - 0s 7ms/step - loss: 3.2696 - accuracy: 0.3734 - val_loss: 3.0624 - val_accuracy: 0.3320
# Epoch 6/200
# 51/51 [==============================] - 0s 7ms/step - loss: 3.2154 - accuracy: 0.3690 - val_loss: 2.9450 - val_accuracy: 0.3880
# Epoch 7/200
# 51/51 [==============================] - 0s 7ms/step - loss: 3.0379 - accuracy: 0.3882 - val_loss: 3.0332 - val_accuracy: 0.3040
# Epoch 8/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.9142 - accuracy: 0.4149 - val_loss: 2.7360 - val_accuracy: 0.4240
# Epoch 9/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.8167 - accuracy: 0.4260 - val_loss: 2.7561 - val_accuracy: 0.4360
# Epoch 10/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.6803 - accuracy: 0.4718 - val_loss: 2.6824 - val_accuracy: 0.3860
# Epoch 11/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.6008 - accuracy: 0.4644 - val_loss: 2.5287 - val_accuracy: 0.4420
# Epoch 12/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.5373 - accuracy: 0.4755 - val_loss: 2.4722 - val_accuracy: 0.4480
# Epoch 13/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.4426 - accuracy: 0.4972 - val_loss: 2.6649 - val_accuracy: 0.3520
# Epoch 14/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.3403 - accuracy: 0.5009 - val_loss: 2.3681 - val_accuracy: 0.4720
# Epoch 15/200
# 51/51 [==============================] - 1s 10ms/step - loss: 2.2434 - accuracy: 0.5307 - val_loss: 2.3200 - val_accuracy: 0.4480
# Epoch 16/200
# 51/51 [==============================] - 0s 10ms/step - loss: 2.2246 - accuracy: 0.5077 - val_loss: 2.3009 - val_accuracy: 0.4460
# Epoch 17/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.1627 - accuracy: 0.5245 - val_loss: 2.1198 - val_accuracy: 0.5180
# Epoch 18/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.0547 - accuracy: 0.5511 - val_loss: 2.1102 - val_accuracy: 0.4980
# Epoch 19/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.0041 - accuracy: 0.5659 - val_loss: 2.0300 - val_accuracy: 0.5260
# Epoch 20/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.9356 - accuracy: 0.5697 - val_loss: 2.0070 - val_accuracy: 0.4860
# Epoch 21/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.8983 - accuracy: 0.5647 - val_loss: 2.0113 - val_accuracy: 0.4900
# Epoch 22/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.8224 - accuracy: 0.5820 - val_loss: 1.8929 - val_accuracy: 0.5320
# Epoch 23/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.7754 - accuracy: 0.6025 - val_loss: 1.9052 - val_accuracy: 0.5140
# Epoch 24/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.7675 - accuracy: 0.5913 - val_loss: 1.8518 - val_accuracy: 0.5620
# Epoch 25/200
# 51/51 [==============================] - 1s 10ms/step - loss: 1.7585 - accuracy: 0.5746 - val_loss: 1.7632 - val_accuracy: 0.5500
# Epoch 26/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.6978 - accuracy: 0.6050 - val_loss: 1.7987 - val_accuracy: 0.5520
# Epoch 27/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.6713 - accuracy: 0.5926 - val_loss: 1.7266 - val_accuracy: 0.5780
# Epoch 28/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.6206 - accuracy: 0.6099 - val_loss: 1.7784 - val_accuracy: 0.5240
# Epoch 29/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.5953 - accuracy: 0.6328 - val_loss: 1.7609 - val_accuracy: 0.5280
# Epoch 30/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.5589 - accuracy: 0.6322 - val_loss: 1.7855 - val_accuracy: 0.5240
# Epoch 31/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.5647 - accuracy: 0.6130 - val_loss: 1.7743 - val_accuracy: 0.5420
# Epoch 32/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.5245 - accuracy: 0.6204 - val_loss: 1.6879 - val_accuracy: 0.5840
# Epoch 33/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.5021 - accuracy: 0.6272 - val_loss: 1.6028 - val_accuracy: 0.5640
# Epoch 34/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.4544 - accuracy: 0.6390 - val_loss: 1.6169 - val_accuracy: 0.5760
# Epoch 35/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.4377 - accuracy: 0.6526 - val_loss: 1.6813 - val_accuracy: 0.5420
# Epoch 36/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.4457 - accuracy: 0.6477 - val_loss: 1.7961 - val_accuracy: 0.5460
# Epoch 37/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.4287 - accuracy: 0.6526 - val_loss: 1.4754 - val_accuracy: 0.6280
# Epoch 38/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3982 - accuracy: 0.6594 - val_loss: 1.5253 - val_accuracy: 0.6120
# Epoch 39/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3715 - accuracy: 0.6774 - val_loss: 1.5247 - val_accuracy: 0.5900
# Epoch 40/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3695 - accuracy: 0.6774 - val_loss: 1.6878 - val_accuracy: 0.5540
# Epoch 41/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3563 - accuracy: 0.6830 - val_loss: 1.6354 - val_accuracy: 0.5420
# Epoch 42/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3669 - accuracy: 0.6619 - val_loss: 1.5010 - val_accuracy: 0.6380
# Epoch 43/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3329 - accuracy: 0.6731 - val_loss: 1.5453 - val_accuracy: 0.5980
# Epoch 44/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3253 - accuracy: 0.6885 - val_loss: 1.5418 - val_accuracy: 0.5920
# Epoch 45/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3347 - accuracy: 0.6799 - val_loss: 1.6043 - val_accuracy: 0.5800
# Epoch 46/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3076 - accuracy: 0.6793 - val_loss: 1.5183 - val_accuracy: 0.6060
# Epoch 47/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3152 - accuracy: 0.6805 - val_loss: 1.6033 - val_accuracy: 0.6020
# Epoch 48/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3246 - accuracy: 0.6935 - val_loss: 1.4416 - val_accuracy: 0.6480
# Epoch 49/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3260 - accuracy: 0.6768 - val_loss: 1.6094 - val_accuracy: 0.5980
# Epoch 50/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3119 - accuracy: 0.6954 - val_loss: 1.5699 - val_accuracy: 0.5900
# Epoch 51/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2838 - accuracy: 0.6929 - val_loss: 1.6700 - val_accuracy: 0.5540
# Epoch 52/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2526 - accuracy: 0.7207 - val_loss: 1.5340 - val_accuracy: 0.6220
# Epoch 53/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2977 - accuracy: 0.6997 - val_loss: 1.4919 - val_accuracy: 0.6240
# Epoch 54/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2688 - accuracy: 0.7133 - val_loss: 1.4607 - val_accuracy: 0.6440
# Epoch 55/200
# 51/51 [==============================] - 0s 10ms/step - loss: 1.2314 - accuracy: 0.7245 - val_loss: 1.4569 - val_accuracy: 0.6380
# Epoch 56/200
# 51/51 [==============================] - 0s 9ms/step - loss: 1.2255 - accuracy: 0.7325 - val_loss: 1.4136 - val_accuracy: 0.6520
# Epoch 57/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2402 - accuracy: 0.7300 - val_loss: 1.7114 - val_accuracy: 0.5220
# Epoch 58/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2493 - accuracy: 0.7059 - val_loss: 1.5277 - val_accuracy: 0.6080
# Epoch 59/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2865 - accuracy: 0.7077 - val_loss: 1.6528 - val_accuracy: 0.5760
# Epoch 60/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2399 - accuracy: 0.7251 - val_loss: 1.5536 - val_accuracy: 0.6080
# Epoch 61/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2470 - accuracy: 0.7232 - val_loss: 1.4406 - val_accuracy: 0.6420
# Epoch 62/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2553 - accuracy: 0.7325 - val_loss: 1.4721 - val_accuracy: 0.6400
# Epoch 63/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2359 - accuracy: 0.7189 - val_loss: 1.4874 - val_accuracy: 0.6340
# Epoch 64/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2328 - accuracy: 0.7288 - val_loss: 1.4678 - val_accuracy: 0.6400
# Epoch 65/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2083 - accuracy: 0.7449 - val_loss: 1.4347 - val_accuracy: 0.6420
# Epoch 66/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2776 - accuracy: 0.7133 - val_loss: 1.5052 - val_accuracy: 0.6520
# Epoch 67/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2550 - accuracy: 0.7090 - val_loss: 1.4395 - val_accuracy: 0.6520
# Epoch 68/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2179 - accuracy: 0.7325 - val_loss: 1.4719 - val_accuracy: 0.6320
# Epoch 69/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2514 - accuracy: 0.7226 - val_loss: 1.4305 - val_accuracy: 0.6500
# Epoch 70/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2438 - accuracy: 0.7251 - val_loss: 1.5697 - val_accuracy: 0.6000
# Epoch 71/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1860 - accuracy: 0.7467 - val_loss: 1.6024 - val_accuracy: 0.5800
# Epoch 72/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2335 - accuracy: 0.7245 - val_loss: 1.5419 - val_accuracy: 0.6160
# Epoch 73/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2024 - accuracy: 0.7276 - val_loss: 1.4551 - val_accuracy: 0.6460
# Epoch 74/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2025 - accuracy: 0.7381 - val_loss: 1.5681 - val_accuracy: 0.6280
# Epoch 75/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1989 - accuracy: 0.7325 - val_loss: 1.4534 - val_accuracy: 0.6360
# Epoch 76/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2016 - accuracy: 0.7455 - val_loss: 1.4920 - val_accuracy: 0.6200
# Epoch 77/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2129 - accuracy: 0.7294 - val_loss: 1.5060 - val_accuracy: 0.6480
# Epoch 78/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1805 - accuracy: 0.7461 - val_loss: 1.4425 - val_accuracy: 0.6460
# Epoch 79/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2292 - accuracy: 0.7282 - val_loss: 1.4498 - val_accuracy: 0.6480
# Epoch 80/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1979 - accuracy: 0.7461 - val_loss: 1.4734 - val_accuracy: 0.6380
# Epoch 81/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1979 - accuracy: 0.7443 - val_loss: 1.5219 - val_accuracy: 0.6220
# Epoch 82/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1979 - accuracy: 0.7467 - val_loss: 1.5141 - val_accuracy: 0.6260
# Epoch 83/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2285 - accuracy: 0.7331 - val_loss: 1.4419 - val_accuracy: 0.6400
# Epoch 84/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1725 - accuracy: 0.7418 - val_loss: 1.4363 - val_accuracy: 0.6640
# Epoch 85/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1439 - accuracy: 0.7641 - val_loss: 1.3919 - val_accuracy: 0.6540
# Epoch 86/200
# 51/51 [==============================] - 1s 11ms/step - loss: 1.1636 - accuracy: 0.7498 - val_loss: 1.4131 - val_accuracy: 0.6460
# Epoch 87/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2429 - accuracy: 0.7220 - val_loss: 1.4471 - val_accuracy: 0.6240
# Epoch 88/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2076 - accuracy: 0.7319 - val_loss: 1.3998 - val_accuracy: 0.6640
# Epoch 89/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1781 - accuracy: 0.7455 - val_loss: 1.4561 - val_accuracy: 0.6380
# Epoch 90/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1951 - accuracy: 0.7437 - val_loss: 1.4497 - val_accuracy: 0.6180
# Epoch 91/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2058 - accuracy: 0.7418 - val_loss: 1.4857 - val_accuracy: 0.6340
# Epoch 92/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1815 - accuracy: 0.7430 - val_loss: 1.4590 - val_accuracy: 0.6180
# Epoch 93/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1565 - accuracy: 0.7560 - val_loss: 1.4542 - val_accuracy: 0.6400
# Epoch 94/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1580 - accuracy: 0.7567 - val_loss: 1.4896 - val_accuracy: 0.6300
# Epoch 95/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1820 - accuracy: 0.7548 - val_loss: 1.3909 - val_accuracy: 0.6520
# Epoch 96/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1952 - accuracy: 0.7443 - val_loss: 1.4322 - val_accuracy: 0.6480
# Epoch 97/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1718 - accuracy: 0.7647 - val_loss: 1.4967 - val_accuracy: 0.6280
# Epoch 98/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1938 - accuracy: 0.7381 - val_loss: 1.4781 - val_accuracy: 0.6220
# Epoch 99/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2371 - accuracy: 0.7238 - val_loss: 1.4199 - val_accuracy: 0.6660
# Epoch 100/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1617 - accuracy: 0.7480 - val_loss: 1.4466 - val_accuracy: 0.6440
# Epoch 101/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1788 - accuracy: 0.7542 - val_loss: 1.4614 - val_accuracy: 0.6400
# Epoch 102/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1865 - accuracy: 0.7511 - val_loss: 1.4670 - val_accuracy: 0.6480
# Epoch 103/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1370 - accuracy: 0.7573 - val_loss: 1.4889 - val_accuracy: 0.6420
# Epoch 104/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1967 - accuracy: 0.7387 - val_loss: 1.4737 - val_accuracy: 0.6540
# Epoch 105/200
# 51/51 [==============================] - 0s 10ms/step - loss: 1.1948 - accuracy: 0.7362 - val_loss: 1.4344 - val_accuracy: 0.6480
# Epoch 106/200
# 51/51 [==============================] - 1s 10ms/step - loss: 1.1724 - accuracy: 0.7480 - val_loss: 1.4225 - val_accuracy: 0.6540
# Epoch 107/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1690 - accuracy: 0.7610 - val_loss: 1.4397 - val_accuracy: 0.6480
# Epoch 108/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1682 - accuracy: 0.7498 - val_loss: 1.4156 - val_accuracy: 0.6520
# Epoch 109/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1499 - accuracy: 0.7579 - val_loss: 1.4543 - val_accuracy: 0.6620
# Epoch 110/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1688 - accuracy: 0.7437 - val_loss: 1.3822 - val_accuracy: 0.6880
# Epoch 111/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1613 - accuracy: 0.7616 - val_loss: 1.4153 - val_accuracy: 0.6600
# Epoch 112/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1446 - accuracy: 0.7567 - val_loss: 1.5228 - val_accuracy: 0.6080
# Epoch 113/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1335 - accuracy: 0.7647 - val_loss: 1.4155 - val_accuracy: 0.6660
# Epoch 114/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1466 - accuracy: 0.7721 - val_loss: 1.4333 - val_accuracy: 0.6460
# Epoch 115/200
# 51/51 [==============================] - 1s 10ms/step - loss: 1.1551 - accuracy: 0.7635 - val_loss: 1.3416 - val_accuracy: 0.6820
# Epoch 116/200
# 51/51 [==============================] - 0s 9ms/step - loss: 1.1440 - accuracy: 0.7591 - val_loss: 1.4458 - val_accuracy: 0.6280
# Epoch 117/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1104 - accuracy: 0.7789 - val_loss: 1.5163 - val_accuracy: 0.6200
# Epoch 118/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1653 - accuracy: 0.7505 - val_loss: 1.4239 - val_accuracy: 0.6660
# Epoch 119/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1490 - accuracy: 0.7659 - val_loss: 1.4608 - val_accuracy: 0.6420
# Epoch 120/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1825 - accuracy: 0.7449 - val_loss: 1.4797 - val_accuracy: 0.6480
# Epoch 121/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1679 - accuracy: 0.7467 - val_loss: 1.4569 - val_accuracy: 0.6540
# Epoch 122/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1397 - accuracy: 0.7734 - val_loss: 1.3938 - val_accuracy: 0.6780
# Epoch 123/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1544 - accuracy: 0.7628 - val_loss: 1.4479 - val_accuracy: 0.6520
# Epoch 124/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1686 - accuracy: 0.7536 - val_loss: 1.4636 - val_accuracy: 0.6440
# Epoch 125/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1775 - accuracy: 0.7567 - val_loss: 1.4474 - val_accuracy: 0.6420
# Epoch 126/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1819 - accuracy: 0.7480 - val_loss: 1.4354 - val_accuracy: 0.6500
# Epoch 127/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1624 - accuracy: 0.7641 - val_loss: 1.5062 - val_accuracy: 0.6440
# Epoch 128/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1330 - accuracy: 0.7783 - val_loss: 1.4525 - val_accuracy: 0.6440
# Epoch 129/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1029 - accuracy: 0.7771 - val_loss: 1.4983 - val_accuracy: 0.6380
# Epoch 130/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1762 - accuracy: 0.7406 - val_loss: 1.4807 - val_accuracy: 0.6260
# Epoch 131/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2061 - accuracy: 0.7313 - val_loss: 1.4221 - val_accuracy: 0.6540
# Epoch 132/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1546 - accuracy: 0.7573 - val_loss: 1.3725 - val_accuracy: 0.6700
# Epoch 133/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1341 - accuracy: 0.7678 - val_loss: 1.3319 - val_accuracy: 0.6820
# Epoch 134/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1679 - accuracy: 0.7443 - val_loss: 1.4719 - val_accuracy: 0.6460
# Epoch 135/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2021 - accuracy: 0.7461 - val_loss: 1.4909 - val_accuracy: 0.6120
# Epoch 136/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1543 - accuracy: 0.7517 - val_loss: 1.4155 - val_accuracy: 0.6900
# Epoch 137/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1586 - accuracy: 0.7591 - val_loss: 1.3749 - val_accuracy: 0.6660
# Epoch 138/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1277 - accuracy: 0.7715 - val_loss: 1.4918 - val_accuracy: 0.6380
# Epoch 139/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1251 - accuracy: 0.7690 - val_loss: 1.4381 - val_accuracy: 0.6520
# Epoch 140/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1482 - accuracy: 0.7461 - val_loss: 1.4107 - val_accuracy: 0.6460
# Epoch 141/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0913 - accuracy: 0.7851 - val_loss: 1.4263 - val_accuracy: 0.6380
# Epoch 142/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1306 - accuracy: 0.7721 - val_loss: 1.4087 - val_accuracy: 0.6620
# Epoch 143/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1261 - accuracy: 0.7690 - val_loss: 1.3371 - val_accuracy: 0.6740
# Epoch 144/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1104 - accuracy: 0.7789 - val_loss: 1.4321 - val_accuracy: 0.6520
# Epoch 145/200
# 51/51 [==============================] - 1s 10ms/step - loss: 1.1879 - accuracy: 0.7505 - val_loss: 1.3276 - val_accuracy: 0.6640
# Epoch 146/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.0872 - accuracy: 0.7833 - val_loss: 1.4313 - val_accuracy: 0.6640
# Epoch 147/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1431 - accuracy: 0.7604 - val_loss: 1.4676 - val_accuracy: 0.6260
# Epoch 148/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1360 - accuracy: 0.7585 - val_loss: 1.4520 - val_accuracy: 0.6700
# Epoch 149/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1298 - accuracy: 0.7628 - val_loss: 1.3627 - val_accuracy: 0.6960
# Epoch 150/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1180 - accuracy: 0.7728 - val_loss: 1.5076 - val_accuracy: 0.6240
# Epoch 151/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1167 - accuracy: 0.7771 - val_loss: 1.3892 - val_accuracy: 0.6680
# Epoch 152/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1572 - accuracy: 0.7505 - val_loss: 1.4255 - val_accuracy: 0.6740
# Epoch 153/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1487 - accuracy: 0.7474 - val_loss: 1.3826 - val_accuracy: 0.6840
# Epoch 154/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1176 - accuracy: 0.7591 - val_loss: 1.4003 - val_accuracy: 0.6580
# Epoch 155/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1138 - accuracy: 0.7653 - val_loss: 1.3514 - val_accuracy: 0.6900
# Epoch 156/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1552 - accuracy: 0.7579 - val_loss: 1.3915 - val_accuracy: 0.6440
# Epoch 157/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1515 - accuracy: 0.7579 - val_loss: 1.3838 - val_accuracy: 0.6920
# Epoch 158/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1266 - accuracy: 0.7728 - val_loss: 1.4781 - val_accuracy: 0.6340
# Epoch 159/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1513 - accuracy: 0.7554 - val_loss: 1.3827 - val_accuracy: 0.6500
# Epoch 160/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1362 - accuracy: 0.7678 - val_loss: 1.5302 - val_accuracy: 0.6260
# Epoch 161/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1307 - accuracy: 0.7635 - val_loss: 1.3755 - val_accuracy: 0.6700
# Epoch 162/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1378 - accuracy: 0.7536 - val_loss: 1.4212 - val_accuracy: 0.6620
# Epoch 163/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1122 - accuracy: 0.7796 - val_loss: 1.4595 - val_accuracy: 0.6240
# Epoch 164/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1104 - accuracy: 0.7721 - val_loss: 1.4200 - val_accuracy: 0.6600
# Epoch 165/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0729 - accuracy: 0.7820 - val_loss: 1.5152 - val_accuracy: 0.6400
# Epoch 166/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1051 - accuracy: 0.7690 - val_loss: 1.5091 - val_accuracy: 0.6420
# Epoch 167/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1382 - accuracy: 0.7591 - val_loss: 1.3719 - val_accuracy: 0.6780
# Epoch 168/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1094 - accuracy: 0.7858 - val_loss: 1.3259 - val_accuracy: 0.6820
# Epoch 169/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0988 - accuracy: 0.7728 - val_loss: 1.4012 - val_accuracy: 0.6360
# Epoch 170/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1077 - accuracy: 0.7783 - val_loss: 1.4643 - val_accuracy: 0.6440
# Epoch 171/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1520 - accuracy: 0.7653 - val_loss: 1.4327 - val_accuracy: 0.6580
# Epoch 172/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0904 - accuracy: 0.7759 - val_loss: 1.3810 - val_accuracy: 0.6660
# Epoch 173/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1232 - accuracy: 0.7666 - val_loss: 1.4092 - val_accuracy: 0.6720
# Epoch 174/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1435 - accuracy: 0.7628 - val_loss: 1.3726 - val_accuracy: 0.6760
# Epoch 175/200
# 51/51 [==============================] - 0s 9ms/step - loss: 1.1556 - accuracy: 0.7635 - val_loss: 1.4615 - val_accuracy: 0.6560
# Epoch 176/200
# 51/51 [==============================] - 0s 9ms/step - loss: 1.1174 - accuracy: 0.7659 - val_loss: 1.4185 - val_accuracy: 0.6500
# Epoch 177/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1190 - accuracy: 0.7746 - val_loss: 1.3990 - val_accuracy: 0.6700
# Epoch 178/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0983 - accuracy: 0.7728 - val_loss: 1.4211 - val_accuracy: 0.6480
# Epoch 179/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0894 - accuracy: 0.7920 - val_loss: 1.4116 - val_accuracy: 0.6760
# Epoch 180/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1338 - accuracy: 0.7579 - val_loss: 1.4092 - val_accuracy: 0.6660
# Epoch 181/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1171 - accuracy: 0.7728 - val_loss: 1.3261 - val_accuracy: 0.6840
# Epoch 182/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1387 - accuracy: 0.7647 - val_loss: 1.5180 - val_accuracy: 0.6120
# Epoch 183/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1850 - accuracy: 0.7511 - val_loss: 1.4040 - val_accuracy: 0.6620
# Epoch 184/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1378 - accuracy: 0.7703 - val_loss: 1.4252 - val_accuracy: 0.6540
# Epoch 185/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1525 - accuracy: 0.7517 - val_loss: 1.3806 - val_accuracy: 0.6760
# Epoch 186/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1150 - accuracy: 0.7814 - val_loss: 1.3406 - val_accuracy: 0.6740
# Epoch 187/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1704 - accuracy: 0.7486 - val_loss: 1.4050 - val_accuracy: 0.6800
# Epoch 188/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1259 - accuracy: 0.7690 - val_loss: 1.3834 - val_accuracy: 0.6800
# Epoch 189/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0698 - accuracy: 0.7944 - val_loss: 1.3605 - val_accuracy: 0.6760
# Epoch 190/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0564 - accuracy: 0.7926 - val_loss: 1.3661 - val_accuracy: 0.6660
# Epoch 191/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1118 - accuracy: 0.7709 - val_loss: 1.3396 - val_accuracy: 0.6660
# Epoch 192/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1098 - accuracy: 0.7703 - val_loss: 1.4143 - val_accuracy: 0.6500
# Epoch 193/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1202 - accuracy: 0.7666 - val_loss: 1.4373 - val_accuracy: 0.6600
# Epoch 194/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1371 - accuracy: 0.7604 - val_loss: 1.4193 - val_accuracy: 0.6820
# Epoch 195/200
# 51/51 [==============================] - 1s 11ms/step - loss: 1.1347 - accuracy: 0.7666 - val_loss: 1.5240 - val_accuracy: 0.6260
# Epoch 196/200
# 51/51 [==============================] - 1s 10ms/step - loss: 1.1453 - accuracy: 0.7653 - val_loss: 1.3252 - val_accuracy: 0.6800
# Epoch 197/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1277 - accuracy: 0.7746 - val_loss: 1.3216 - val_accuracy: 0.6920
# Epoch 198/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1108 - accuracy: 0.7734 - val_loss: 1.3272 - val_accuracy: 0.6900
# Epoch 199/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0918 - accuracy: 0.7789 - val_loss: 1.3724 - val_accuracy: 0.6900
# Epoch 200/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1394 - accuracy: 0.7622 - val_loss: 1.3284 - val_accuracy: 0.6940

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(basic_cnn_model_results.history['accuracy'])
plt.plot(basic_cnn_model_results.history['val_accuracy'])
plt.title('Basic CNN model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(basic_cnn_model_results.history['loss'],'o')
plt.plot(basic_cnn_model_results.history['val_loss'],'o')
plt.title('Basic CNN model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the basic CNN model

cnn_score = basic_cnn_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the basic CNN model:',cnn_score[1])
# Out:
# Test accuracy of the basic CNN model: 0.7065462470054626
