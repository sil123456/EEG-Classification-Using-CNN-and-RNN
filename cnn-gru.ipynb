# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
os.chdir("/kaggle/input/eegdata")
# Out:
# /kaggle/input/eegdata/y_test.npy
# /kaggle/input/eegdata/main.py
# /kaggle/input/eegdata/y_train_valid.npy
# /kaggle/input/eegdata/person_train_valid.npy
# /kaggle/input/eegdata/EEG_pl.py
# /kaggle/input/eegdata/X_test.npy
# /kaggle/input/eegdata/dataset.py
# /kaggle/input/eegdata/EEG_loading.ipynb
# /kaggle/input/eegdata/person_test.npy
# /kaggle/input/eegdata/X_train_valid.npy
# /kaggle/input/eegdata/classifier.py

# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,BatchNormalization,MaxPooling2D,Reshape, CuDNNGRU
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras import regularizers
from keras.callbacks import EarlyStopping

# %%
## Loading the numpy arrays corresponding to the EEG dataset

X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Printing the shapes of the numpy arrays

print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %%
## Adjusting the labels to {0,1,2,3}

# Cue onset left is 769 - 0
# Cue onset right is 770 - 1
# Cue onset foot is 771 - 2
# Cue onset tongue is 772 - 3

y_train_valid -= 769
y_test -= 769

# %%
## Creating the training and validation sets

# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(2115, 500, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(x_train, x_valid) = X_train_valid[ind_train], X_train_valid[ind_valid] 
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of training set: (1615, 22, 1000)
# Shape of validation set: (500, 22, 1000)
# Shape of training labels: (1615,)
# Shape of validation labels: (500,)
# Shape of training labels after categorical conversion: (1615, 4)
# Shape of validation labels after categorical conversion: (500, 4)
# Shape of test labels after categorical conversion: (443, 4)
# Shape of training set after adding width info: (1615, 22, 1000, 1)
# Shape of validation set after adding width info: (500, 22, 1000, 1)
# Shape of test set after adding width info: (443, 22, 1000, 1)
# Shape of training set after dimension reshaping: (1615, 1000, 1, 22)
# Shape of validation set after dimension reshaping: (500, 1000, 1, 22)
# Shape of test set after dimension reshaping: (443, 1000, 1, 22)

# %%
# Building the CNN model using sequential class
hybrid_cnn_gru_model = Sequential()

# Conv. block 1
hybrid_cnn_gru_model.add(Conv2D(filters=16, kernel_size=(10,1), padding='same', activation='elu', input_shape=(1000,1,22), kernel_regularizer=regularizers.l2(0.01)))
hybrid_cnn_gru_model.add(MaxPooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.5))

# Conv. block 2
hybrid_cnn_gru_model.add(Conv2D(filters=32, kernel_size=(10,1), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01)))
hybrid_cnn_gru_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.5))

# Conv. block 3
hybrid_cnn_gru_model.add(Conv2D(filters=64, kernel_size=(10,1), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01)))
hybrid_cnn_gru_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.5))

# Conv. block 4
hybrid_cnn_gru_model.add(Conv2D(filters=128, kernel_size=(10,1), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01)))
hybrid_cnn_gru_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.5))

# FC+GRU layers
hybrid_cnn_gru_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
hybrid_cnn_gru_model.add(Dense((100))) # FC layer with 100 units
hybrid_cnn_gru_model.add(Reshape((100,1))) # Reshape my output of FC layer so that it's compatible
hybrid_cnn_gru_model.add(CuDNNGRU(10, input_shape=(100,1), return_sequences=False))


# Output layer with Softmax activation 
hybrid_cnn_gru_model.add(Dense(4, activation='softmax', kernel_regularizer=regularizers.l2(0.01))) # Output FC layer with softmax activation


# Printing the model summary
hybrid_cnn_gru_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 1000, 1, 16)       3536
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 334, 1, 16)        0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 334, 1, 16)        64
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 334, 1, 16)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 334, 1, 32)        5152
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 112, 1, 32)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 112, 1, 32)        128
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 112, 1, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 112, 1, 64)        20544
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 38, 1, 64)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 38, 1, 64)         256
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 38, 1, 64)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 38, 1, 128)        82048
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 13, 1, 128)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 13, 1, 128)        512
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 13, 1, 128)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1664)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               166500
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 100, 1)            0
# _________________________________________________________________
# cu_dnngru_3 (CuDNNGRU)       (None, 10)                390
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 44
# =================================================================
# Total params: 279,174
# Trainable params: 278,694
# Non-trainable params: 480
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

learning_rate = 5e-4
epochs = 200
hybrid_cnn_gru_optimizer = Adam(learning_rate=learning_rate)

# %%
# Compiling the model
hybrid_cnn_gru_model.compile(loss='categorical_crossentropy',
                 optimizer=hybrid_cnn_gru_optimizer,
                 metrics=['accuracy'])

#callbacks = [EarlyStopping(monitor='val_accuracy', patience=25)]

# Training and validating the model
hybrid_cnn_gru_model_results = hybrid_cnn_gru_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), 
             #callbacks=callbacks,                                             
             verbose=True)
# Out:
# Epoch 1/200
# 26/26 [==============================] - 2s 29ms/step - loss: 3.0857 - accuracy: 0.2743 - val_loss: 2.9674 - val_accuracy: 0.3180
# Epoch 2/200
# 26/26 [==============================] - 0s 14ms/step - loss: 2.9315 - accuracy: 0.2793 - val_loss: 2.8246 - val_accuracy: 0.3720
# Epoch 3/200
# 26/26 [==============================] - 0s 14ms/step - loss: 2.7713 - accuracy: 0.3176 - val_loss: 2.6869 - val_accuracy: 0.3580
# Epoch 4/200
# 26/26 [==============================] - 0s 14ms/step - loss: 2.6489 - accuracy: 0.3183 - val_loss: 2.5709 - val_accuracy: 0.3500
# Epoch 5/200
# 26/26 [==============================] - 0s 14ms/step - loss: 2.5170 - accuracy: 0.3474 - val_loss: 2.4606 - val_accuracy: 0.3320
# Epoch 6/200
# 26/26 [==============================] - 0s 14ms/step - loss: 2.4134 - accuracy: 0.3536 - val_loss: 2.3521 - val_accuracy: 0.3640
# Epoch 7/200
# 26/26 [==============================] - 0s 14ms/step - loss: 2.2952 - accuracy: 0.3672 - val_loss: 2.2582 - val_accuracy: 0.3580
# Epoch 8/200
# 26/26 [==============================] - 0s 14ms/step - loss: 2.2116 - accuracy: 0.3709 - val_loss: 2.1549 - val_accuracy: 0.4140
# Epoch 9/200
# 26/26 [==============================] - 0s 14ms/step - loss: 2.1224 - accuracy: 0.3981 - val_loss: 2.1042 - val_accuracy: 0.3720
# Epoch 10/200
# 26/26 [==============================] - 0s 14ms/step - loss: 2.0364 - accuracy: 0.4025 - val_loss: 2.1037 - val_accuracy: 0.3360
# Epoch 11/200
# 26/26 [==============================] - 0s 14ms/step - loss: 1.9804 - accuracy: 0.4062 - val_loss: 1.9460 - val_accuracy: 0.4180
# Epoch 12/200
# 26/26 [==============================] - 0s 15ms/step - loss: 1.9221 - accuracy: 0.4279 - val_loss: 1.8961 - val_accuracy: 0.4440
# Epoch 13/200
# 26/26 [==============================] - 0s 14ms/step - loss: 1
200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.9168 - accuracy: 0.8000 - val_loss: 1.3841 - val_accuracy: 0.6060
# Epoch 99/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.9362 - accuracy: 0.7820 - val_loss: 1.3658 - val_accuracy: 0.6140
# Epoch 100/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.9127 - accuracy: 0.8025 - val_loss: 1.4280 - val_accuracy: 0.5900
# Epoch 101/200
# 26/26 [==============================] - 1s 30ms/step - loss: 0.9148 - accuracy: 0.7988 - val_loss: 1.4569 - val_accuracy: 0.5820
# Epoch 102/200
# 26/26 [==============================] - 1s 28ms/step - loss: 0.9393 - accuracy: 0.7870 - val_loss: 1.3787 - val_accuracy: 0.6100
# Epoch 103/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.8872 - accuracy: 0.8136 - val_loss: 1.3278 - val_accuracy: 0.6320
# Epoch 104/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.8658 - accuracy: 0.8161 - val_loss: 1.4465 - val_accuracy: 0.5660
# Epoch 105/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.8809 - accuracy: 0.8074 - val_loss: 1.3726 - val_accuracy: 0.6140
# Epoch 106/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.9267 - accuracy: 0.7851 - val_loss: 1.5841 - val_accuracy: 0.5320
# Epoch 107/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.9105 - accuracy: 0.7895 - val_loss: 1.4244 - val_accuracy: 0.5940
# Epoch 108/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.8995 - accuracy: 0.8031 - val_loss: 1.4128 - val_accuracy: 0.6240
# Epoch 109/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8744 - accuracy: 0.8142 - val_loss: 1.4771 - val_accuracy: 0.5740
# Epoch 110/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.9056 - accuracy: 0.7969 - val_loss: 1.5272 - val_accuracy: 0.5480
# Epoch 111/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8995 - accuracy: 0.8050 - val_loss: 1.4247 - val_accuracy: 0.5920
# Epoch 112/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.9063 - accuracy: 0.8043 - val_loss: 1.4162 - val_accuracy: 0.6020
# Epoch 113/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8933 - accuracy: 0.8161 - val_loss: 1.4632 - val_accuracy: 0.5840
# Epoch 114/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8778 - accuracy: 0.8118 - val_loss: 1.4389 - val_accuracy: 0.5900
# Epoch 115/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8763 - accuracy: 0.8235 - val_loss: 1.3888 - val_accuracy: 0.6300
# Epoch 116/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.9100 - accuracy: 0.7994 - val_loss: 1.3940 - val_accuracy: 0.6060
# Epoch 117/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8608 - accuracy: 0.8235 - val_loss: 1.4177 - val_accuracy: 0.5820
# Epoch 118/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8968 - accuracy: 0.7926 - val_loss: 1.3960 - val_accuracy: 0.6180
# Epoch 119/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8832 - accuracy: 0.8062 - val_loss: 1.5189 - val_accuracy: 0.5860
# Epoch 120/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8508 - accuracy: 0.8260 - val_loss: 1.4149 - val_accuracy: 0.6380
# Epoch 121/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8337 - accuracy: 0.8378 - val_loss: 1.3714 - val_accuracy: 0.6560
# Epoch 122/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8218 - accuracy: 0.8409 - val_loss: 1.3773 - val_accuracy: 0.6340
# Epoch 123/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8474 - accuracy: 0.8285 - val_loss: 1.4138 - val_accuracy: 0.6140
# Epoch 124/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.8331 - accuracy: 0.8297 - val_loss: 1.4007 - val_accuracy: 0.6320
# Epoch 125/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.8220 - accuracy: 0.8372 - val_loss: 1.3999 - val_accuracy: 0.6200
# Epoch 126/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8330 - accuracy: 0.8204 - val_loss: 1.4269 - val_accuracy: 0.5980
# Epoch 127/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8403 - accuracy: 0.8279 - val_loss: 1.4133 - val_accuracy: 0.6200
# Epoch 128/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.8592 - accuracy: 0.8118 - val_loss: 1.5148 - val_accuracy: 0.6020
# Epoch 129/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.8424 - accuracy: 0.8291 - val_loss: 1.3573 - val_accuracy: 0.6340
# Epoch 130/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8497 - accuracy: 0.8211 - val_loss: 1.5052 - val_accuracy: 0.6020
# Epoch 131/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8540 - accuracy: 0.8241 - val_loss: 1.4788 - val_accuracy: 0.5800
# Epoch 132/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8174 - accuracy: 0.8433 - val_loss: 1.4683 - val_accuracy: 0.5920
# Epoch 133/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8199 - accuracy: 0.8303 - val_loss: 1.4894 - val_accuracy: 0.5720
# Epoch 134/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8419 - accuracy: 0.8297 - val_loss: 1.5649 - val_accuracy: 0.5720
# Epoch 135/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8689 - accuracy: 0.8056 - val_loss: 1.4227 - val_accuracy: 0.6120
# Epoch 136/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8263 - accuracy: 0.8365 - val_loss: 1.4268 - val_accuracy: 0.6360
# Epoch 137/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8039 - accuracy: 0.8415 - val_loss: 1.4492 - val_accuracy: 0.6220
# Epoch 138/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7974 - accuracy: 0.8477 - val_loss: 1.4980 - val_accuracy: 0.5840
# Epoch 139/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8597 - accuracy: 0.8167 - val_loss: 1.4996 - val_accuracy: 0.6080
# Epoch 140/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8224 - accuracy: 0.8471 - val_loss: 1.5119 - val_accuracy: 0.5680
# Epoch 141/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8174 - accuracy: 0.8341 - val_loss: 1.4880 - val_accuracy: 0.5980
# Epoch 142/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8191 - accuracy: 0.8390 - val_loss: 1.4201 - val_accuracy: 0.6360
# Epoch 143/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7997 - accuracy: 0.8458 - val_loss: 1.5414 - val_accuracy: 0.5720
# Epoch 144/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8426 - accuracy: 0.8291 - val_loss: 1.4180 - val_accuracy: 0.6080
# Epoch 145/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8560 - accuracy: 0.8149 - val_loss: 1.4272 - val_accuracy: 0.6140
# Epoch 146/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8159 - accuracy: 0.8415 - val_loss: 1.4168 - val_accuracy: 0.6140
# Epoch 147/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8262 - accuracy: 0.8334 - val_loss: 1.4478 - val_accuracy: 0.6240
# Epoch 148/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8104 - accuracy: 0.8452 - val_loss: 1.3925 - val_accuracy: 0.6460
# Epoch 149/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8040 - accuracy: 0.8378 - val_loss: 1.4691 - val_accuracy: 0.6160
# Epoch 150/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8304 - accuracy: 0.8279 - val_loss: 1.4312 - val_accuracy: 0.6360
# Epoch 151/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8158 - accuracy: 0.8378 - val_loss: 1.3836 - val_accuracy: 0.6460
# Epoch 152/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8049 - accuracy: 0.8415 - val_loss: 1.4448 - val_accuracy: 0.6280
# Epoch 153/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7902 - accuracy: 0.8514 - val_loss: 1.4728 - val_accuracy: 0.5880
# Epoch 154/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.7984 - accuracy: 0.8458 - val_loss: 1.4566 - val_accuracy: 0.6260
# Epoch 155/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7865 - accuracy: 0.8570 - val_loss: 1.3825 - val_accuracy: 0.6420
# Epoch 156/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8038 - accuracy: 0.8458 - val_loss: 1.4314 - val_accuracy: 0.6160
# Epoch 157/200
# 26/26 [==============================] - 0s 19ms/step - loss: 0.7782 - accuracy: 0.8520 - val_loss: 1.4924 - val_accuracy: 0.6120
# Epoch 158/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.7883 - accuracy: 0.8452 - val_loss: 1.4092 - val_accuracy: 0.6340
# Epoch 159/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8009 - accuracy: 0.8464 - val_loss: 1.4332 - val_accuracy: 0.6480
# Epoch 160/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7488 - accuracy: 0.8700 - val_loss: 1.4554 - val_accuracy: 0.6300
# Epoch 161/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7930 - accuracy: 0.8464 - val_loss: 1.4448 - val_accuracy: 0.6200
# Epoch 162/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7970 - accuracy: 0.8334 - val_loss: 1.5233 - val_accuracy: 0.5760
# Epoch 163/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7947 - accuracy: 0.8502 - val_loss: 1.3998 - val_accuracy: 0.6500
# Epoch 164/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7843 - accuracy: 0.8563 - val_loss: 1.4588 - val_accuracy: 0.6140
# Epoch 165/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7901 - accuracy: 0.8483 - val_loss: 1.4961 - val_accuracy: 0.6200
# Epoch 166/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7946 - accuracy: 0.8433 - val_loss: 1.4482 - val_accuracy: 0.6200
# Epoch 167/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.8027 - accuracy: 0.8421 - val_loss: 1.4417 - val_accuracy: 0.6160
# Epoch 168/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7777 - accuracy: 0.8594 - val_loss: 1.4993 - val_accuracy: 0.5980
# Epoch 169/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7525 - accuracy: 0.8718 - val_loss: 1.4677 - val_accuracy: 0.6240
# Epoch 170/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7576 - accuracy: 0.8613 - val_loss: 1.4590 - val_accuracy: 0.6180
# Epoch 171/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7502 - accuracy: 0.8669 - val_loss: 1.4198 - val_accuracy: 0.6260
# Epoch 172/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7477 - accuracy: 0.8693 - val_loss: 1.4564 - val_accuracy: 0.6160
# Epoch 173/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7668 - accuracy: 0.8570 - val_loss: 1.4736 - val_accuracy: 0.6120
# Epoch 174/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7825 - accuracy: 0.8495 - val_loss: 1.5400 - val_accuracy: 0.6080
# Epoch 175/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7794 - accuracy: 0.8471 - val_loss: 1.3776 - val_accuracy: 0.6540
# Epoch 176/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7862 - accuracy: 0.8464 - val_loss: 1.4106 - val_accuracy: 0.6320
# Epoch 177/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7835 - accuracy: 0.8514 - val_loss: 1.4621 - val_accuracy: 0.6160
# Epoch 178/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7756 - accuracy: 0.8607 - val_loss: 1.4859 - val_accuracy: 0.6140
# Epoch 179/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7579 - accuracy: 0.8588 - val_loss: 1.4223 - val_accuracy: 0.6340
# Epoch 180/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7693 - accuracy: 0.8632 - val_loss: 1.4340 - val_accuracy: 0.6300
# Epoch 181/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.7518 - accuracy: 0.8625 - val_loss: 1.3999 - val_accuracy: 0.6480
# Epoch 182/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7813 - accuracy: 0.8520 - val_loss: 1.4008 - val_accuracy: 0.6360
# Epoch 183/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7334 - accuracy: 0.8749 - val_loss: 1.4031 - val_accuracy: 0.6460
# Epoch 184/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.7693 - accuracy: 0.8471 - val_loss: 1.4445 - val_accuracy: 0.6460
# Epoch 185/200
# 26/26 [==============================] - 1s 20ms/step - loss: 0.7795 - accuracy: 0.8514 - val_loss: 1.4782 - val_accuracy: 0.6300
# Epoch 186/200
# 26/26 [==============================] - 1s 25ms/step - loss: 0.7776 - accuracy: 0.8545 - val_loss: 1.4803 - val_accuracy: 0.6260
# Epoch 187/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.7690 - accuracy: 0.8557 - val_loss: 1.4517 - val_accuracy: 0.6260
# Epoch 188/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7556 - accuracy: 0.8638 - val_loss: 1.3959 - val_accuracy: 0.6400
# Epoch 189/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7392 - accuracy: 0.8780 - val_loss: 1.4513 - val_accuracy: 0.6040
# Epoch 190/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7468 - accuracy: 0.8607 - val_loss: 1.4777 - val_accuracy: 0.6300
# Epoch 191/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7337 - accuracy: 0.8743 - val_loss: 1.4876 - val_accuracy: 0.6020
# Epoch 192/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7449 - accuracy: 0.8663 - val_loss: 1.3959 - val_accuracy: 0.6420
# Epoch 193/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7949 - accuracy: 0.8415 - val_loss: 1.4131 - val_accuracy: 0.6300
# Epoch 194/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7513 - accuracy: 0.8576 - val_loss: 1.4976 - val_accuracy: 0.5840
# Epoch 195/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7641 - accuracy: 0.8570 - val_loss: 1.4290 - val_accuracy: 0.6280
# Epoch 196/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7657 - accuracy: 0.8508 - val_loss: 1.4891 - val_accuracy: 0.6240
# Epoch 197/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7380 - accuracy: 0.8811 - val_loss: 1.4184 - val_accuracy: 0.6360
# Epoch 198/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7497 - accuracy: 0.8681 - val_loss: 1.4023 - val_accuracy: 0.6460
# Epoch 199/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7234 - accuracy: 0.8681 - val_loss: 1.5007 - val_accuracy: 0.6080
# Epoch 200/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.7160 - accuracy: 0.8799 - val_loss: 1.4703 - val_accuracy: 0.6140

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_gru_model_results.history['accuracy'])
plt.plot(hybrid_cnn_gru_model_results.history['val_accuracy'])
plt.title('Hybrid CNN-GRU model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_gru_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_gru_model_results.history['val_loss'],'o')
plt.title('Hybrid CNN-GRU model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the hybrid CNN-GRU model

hybrid_cnn_gru_score = hybrid_cnn_gru_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hybrid CNN-GRU model:',hybrid_cnn_gru_score[1])
# Out:
# Test accuracy of the hybrid CNN-GRU model: 0.6252821683883667

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

y_pred_test = hybrid_cnn_gru_model.predict(x_test)


# classification_report
for i,x in enumerate(['left','right','foot','tongue']):
    print(x)
    y_pred = np.where(y_pred_test[:,i]>0.5,1,0)
    
    print(classification_report(y_test[:,i], y_pred))
# Out:
# left
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.91      0.88       332
#          1.0       0.66      0.51      0.58       111
#
#     accuracy                           0.81       443
#    macro avg       0.76      0.71      0.73       443
# weighted avg       0.80      0.81      0.80       443
#
# right
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.75      0.81       316
#          1.0       0.54      0.72      0.62       127
#
#     accuracy                           0.74       443
#    macro avg       0.71      0.74      0.71       443
# weighted avg       0.78      0.74      0.75       443
#
# foot
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.94      0.91       347
#          1.0       0.70      0.51      0.59        96
#
#     accuracy                           0.85       443
#    macro avg       0.79      0.72      0.75       443
# weighted avg       0.84      0.85      0.84       443
#
# tongue
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.94      0.90       334
#          1.0       0.75      0.56      0.64       109
#
#     accuracy                           0.85       443
#    macro avg       0.81      0.75      0.77       443
# weighted avg       0.84      0.85      0.84       443
